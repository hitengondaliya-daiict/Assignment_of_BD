# %%
# Q-1

from sklearn.datasets import fetch_20newsgroups
from sklearn.feature_extraction.text import TfidfVectorizer

data= fetch_20newsgroups()

data1 = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

vectorizer1 = TfidfVectorizer(stop_words='english', max_features=1000)
X = vectorizer1.fit_transform(data1.data)
X.shape
# Out:
# (18846, 1000)

# %%
vectorizer1.get_feature_names_out()
# Out:
# array(['00', '000', '02', '03', '04', '0t', '10', '100', '11', '12',
#        '128', '13', '14', '145', '15', '16', '17', '18', '19', '1990',
#        '1991', '1992', '1993', '1d9', '1st', '1t', '20', '200', '21',
#        '22', '23', '24', '25', '26', '27', '28', '29', '2di', '2tm', '30',
#        '300', '31', '32', '33', '34', '34u', '35', '36', '37', '38', '3d',
#        '3t', '40', '42', '44', '45', '50', '500', '55', '60', '64', '70',
#        '75', '75u', '80', '800', '90', '91', '92', '93', 'a86', 'ability',
#        'able', 'ac', 'accept', 'access', 'according', 'account', 'act',
#        'action', 'actually', 'add', 'added', 'addition', 'address',
#        'administration', 'advance', 'age', 'ago', 'agree', 'ah', 'air',
#        'al', 'algorithm', 'allow', 'allowed', 'alt', 'america',
#        'american', 'analysis', 'anonymous', 'answer', 'answers', 'anti',
#        'anybody', 'apparently', 'appear', 'appears', 'apple',
# ...

# %%
# Q-2

from sklearn.metrics.pairwise import cosine_similarity

def cos(vec1, vec2):

    simil_matrix = cosine_similarity(vec1, vec2)
    simil_score = simil_matrix[0, 0]  # Extract the similarity score from the matrix
    return simil_score

simil_score = cos(X, X)  # we use same sparce matrix so similarity between two vector must be one
print("Cosine Similarity:", simil_score)
# Out:
# Cosine Similarity: 1.0000000000000002

# %%
news_groups = fetch_20newsgroups(subset='all', remove=('headers', 'footers', 'quotes'))

# %%
#Q-3
def simil(input_document, documents, vectorizer, top_n=5):

    ip_vector = vectorizer.transform([input_document])
    doc = vectorizer.transform(doc)
    similarities = cosine_similarity(ipvector, doc)
    sorted = similarities.argsort(axis=1)[:, ::-1]
    top_n = sorted[0][:top_n]
    results = [(documents[i], similarities[0, i]) for i in top_n]
    return results

# %%
input_document = "Your input document goes here. This is the document for which you want to find similar documents."
vectorizer = TfidfVectorizer(stop_words='english')
tfidf_matrix = vectorizer.fit_transform(news_groups.data)
similar_doc = simil(input_document, news_groups.data, vectorizer)
for i, (doc, similarity) in enumerate(similar_doc, start=1):
    print(f"Rank {i}: Similarity = {similarity:.4f}\n{doc}\n{'-'*50}\n")
# Out:
# Rank 1: Similarity = 0.3055
#   (0, 126094)	0.07505414547190394
#   (0, 116030)	0.1758130438999529
#   (0, 113965)	0.21853457959828057
#   (0, 111918)	0.16651568051459437
#   (0, 110706)	0.1684158941322477
#   (0, 107603)	0.09741749065966405
#   (0, 107597)	0.151748942622477
#   (0, 106936)	0.23455060793277183
#   (0, 104933)	0.09130357220152185
#   (0, 104325)	0.3654452458682333
#   (0, 102509)	0.1471121964384594
#   (0, 101003)	0.07741135284120615
#   (0, 100907)	0.13863566430309493
#   (0, 99492)	0.12679604330028435
#   (0, 88286)	0.08790652194997645
#   (0, 86317)	0.07594181844483283
#   (0, 78284)	0.08685740730961508
#   (0, 75411)	0.08317974297040666
#   (0, 74935)	0.1552040594509836
#   (0, 65218)	0.10283476409591145
#   (0, 62855)	0.23455060793277183
#   (0, 62665)	0.11144339769632346
#   (0, 61742)	0.14633761291479044
#   (0, 60355)	0.12045047914416256
#   (0, 60213)	0.10062547952120547
#   (0, 59308)	0.11374119657159479
#   (0, 57968)	0.08230526074286126
# ...
